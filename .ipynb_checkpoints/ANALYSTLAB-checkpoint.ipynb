# %% [markdown]
# # Week 1–2: Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ### Objective
# To prepare datasets for modeling by:
# Cleaning and structuring raw data
#                    Identifying patterns, distributions, and relationships
# Generating insights to guide modeling decisions
#
#
# ### Datasets
# Titanic Dataset
# https://www.kaggle.com/datasets/yasserh/titanic-dataset
#
# House Prices Dataset
# https://www.kaggle.com/datasets/harishkumardatalab/housing-price-prediction
#
#
# ### Task Breakdown
# Load datasets using Python (Pandas)
# Handle missing values and duplicates
# Perform univariate and bivariate analysis
# Visualize distributions and correlations
# Identify important features
#
# ### Tools
# Python (Pandas, NumPy, Matplotlib, Seaborn)
#
# ### Deliverables
# Cleaned dataset
# Jupyter Notebook (EDA)
# Insight summary

# %% [markdown]
# PassengerId-	Unique identifier assigned to each passenger.
#
# Survived-	Whether the passenger survived the disaster. 0 = No, 1 = Yes. This is the target variable.
#
# Pclass-	Passenger ticket class. 1 = First Class, 2 = Second Class, 3 = Third Class. It is often used as an indicator of socioeconomic status.
#
# Name-	Full name of the passenger.
#
# Sex-	Gender of the passenger (male or female).
#
# Age-	Passengers age in years. Some values may be missing.
#
# SibSp-	Number of siblings and spouses aboard the Titanic.
#
# Parch-	Number of parents and children aboard the Titanic.
#
# Ticket-	Ticket number assigned to the passenger.
#
# Fare-	Amount paid for the ticket (in British pounds).
#
# Cabin-	Cabin number where the passenger stayed. Many values are missing.
#
# Embarked-	Port where the passenger boarded the ship. C = Cherbourg, Q = Queenstown, S = Southampton.

# %% [markdown]
# ## REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# # PART 1
# ## TITANIC DATASET

# %%
titanic = pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\\Titanic-Dataset.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(f'The number of rows:{titanic. shape[0]}')
print(f'The number of columns: {titanic.shape[1]}')
# Out:
# The number of rows:891
# The number of columns: 12

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe(include='all').T
# Out:
#              count unique                  top freq       mean         std  \
# PassengerId  891.0    NaN                  NaN  NaN      446.0  257.353842
# Survived     891.0    NaN                  NaN  NaN   0.383838    0.486592
# Pclass       891.0    NaN                  NaN  NaN   2.308642    0.836071
# Name           891    891  Dooley, Mr. Patrick    1        NaN         NaN
# Sex            891      2                 male  577        NaN         NaN
# Age          714.0    NaN                  NaN  NaN  29.699118   14.526497
# SibSp        891.0    NaN                  NaN  NaN   0.523008    1.102743
# Parch        891.0    NaN                  NaN  NaN   0.381594    0.806057
# Ticket         891    681               347082    7        NaN         NaN
# Fare         891.0    NaN                  NaN  NaN  32.204208   49.693429
# Cabin          204    147                   G6    4        NaN         NaN
# ...

# %%
missing = titanic.isnull().sum()
missing_pct = (missing / len(titanic) * 100).round(2)
pd.DataFrame({'missing_count': missing, 'missing_pct': missing_pct}).query('missing_count > 0').sort_values('missing_count', ascending=False)
# Out:
#           missing_count  missing_pct
# Cabin               687        77.10
# Age                 177        19.87
# Embarked              2         0.22

# %%
plt.figure(figsize=(10,4))
sns.heatmap(titanic.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing Value Map - Titanic')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Handling the missing values

# %%
titanic_clean = titanic.copy()

# Impute age using median per (pclass, sex) group
titanic_clean['Age'] = titanic_clean.groupby(['Pclass', 'Sex'])['Age'].transform(lambda x: x.fillna(x.median()))

# Impute embarked with mode
titanic_clean['Embarked'] = titanic_clean['Embarked'].fillna(titanic_clean['Embarked'].mode()[0])

# Impute cabin with mode
titanic_clean['Cabin'] = titanic_clean['Cabin'].fillna(titanic_clean['Cabin'].mode()[0])


print('Remaining missing values:')
print(titanic_clean.isnull().sum().sum())
# Out:
# Remaining missing values:
# 0

# %% [markdown]
# #### Duplicated rows

# %%
duplicated = titanic_clean.duplicated().sum()
print(f'Rows with identical values across all columns: {duplicated}')
# Out:
# Rows with identical values across all columns: 0

# %% [markdown]
# #### Univariate analysis

# %% [markdown]
# #### Feature engineering

# %%
titanic_clean['family_size'] = titanic_clean['SibSp'] + titanic_clean['Parch'] + 1
titanic_clean['is_alone'] = (titanic_clean['family_size'] == 1).astype(int)
titanic_clean[['SibSp','Parch','family_size','is_alone']].head()
# Out:
#    SibSp  Parch  family_size  is_alone
# 0      1      0            2         0
# 1      1      0            2         0
# 2      0      0            1         1
# 3      1      0            2         0
# 4      0      0            1         1

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 9))

sns.countplot(data=titanic_clean, x='Survived', ax=axes[0,0])
axes[0,0].set_title('Survival Count (0=No, 1=Yes)')

sns.histplot(titanic_clean['Age'], bins=30, kde=True, ax=axes[0,1])
axes[0,1].set_title('Age Distribution')

sns.histplot(titanic_clean['Fare'], bins=40, kde=True, ax=axes[0,2])
axes[0,2].set_title('Fare Distribution')

sns.countplot(data=titanic_clean, x='Pclass', ax=axes[1,0])
axes[1,0].set_title('Passenger Class Count')

sns.countplot(data=titanic_clean, x='Sex', ax=axes[1,1])
axes[1,1].set_title('Sex Count')

sns.countplot(data=titanic_clean, x='Embarked', ax=axes[1,2])
axes[1,2].set_title('Embarkation Port Count')

plt.tight_layout()
plt.show()

# %%
print('Survival rate overall: {:.1%}'.format(titanic_clean['Survived'].mean()))
print(titanic_clean['Fare'].describe())
# Out:
# Survival rate overall: 38.4%
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# **Observations:**
# - Fare is heavily right-skewed (most tickets were cheap, a few luxury fares pull the mean up) — a
#   log transform will likely help any model that assumes normally-distributed inputs.
# - Young adults formed the last portion of passengers
# - Most of the passengers were in 3rd class, and there were more male than female passengers.
# - Most passengers embarked at Southernapton port
# - Overall survival rate is close to 38%.

# %% [markdown]
# #### Bivariate analysis

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 9))

sns.barplot(data=titanic_clean, x='Sex', y='Survived', ax=axes[0,0])
axes[0,0].set_title('Survival Rate by Sex')

sns.barplot(data=titanic_clean, x='Pclass', y='Survived', ax=axes[0,1])
axes[0,1].set_title('Survival Rate by Class')

sns.boxplot(data=titanic_clean, x='Survived', y='Age', ax=axes[0,2])
axes[0,2].set_title('Age vs Survival')

sns.boxplot(data=titanic_clean, x='Survived', y='Fare', ax=axes[1,0])
axes[1,0].set_ylim(0, 300)
axes[1,0].set_title('Fare vs Survival (clipped at 300)')


sns.barplot(data=titanic_clean, x='Embarked', y='Survived', ax=axes[1,2])
axes[1,2].set_title('Survival Rate by Embarkation Port')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Correlation heatmaps ( Numeric featutes)

# %%
numeric_columns = titanic_clean.select_dtypes(include=['int64', 'float64'])
print(numeric_columns.head())
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  family_size  \
# 0            1         0       3  22.0      1      0   7.2500            2
# 1            2         1       1  38.0      1      0  71.2833            2
# 2            3         1       3  26.0      0      0   7.9250            1
# 3            4         1       1  35.0      1      0  53.1000            2
# 4            5         0       3  35.0      0      0   8.0500            1
#
#    is_alone
# 0         0
# 1         0
# 2         1
# 3         0
# 4         1

# %%
num_cols = ['PassengerId','Survived','Pclass','Age','SibSp','Parch','Fare']
plt.figure(figsize=(8,6))
sns.heatmap(titanic_clean[num_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlation Heatmap - Titanic (numeric features)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
# - Sex is the single strongest signal: women survived at roughly 3–4x the rate of men.
# - Passenger class matters a lot too — 1st class passengers survived at much higher rates than 3rd class,
#   consistent with `pclass` and `fare` being negatively/positively correlated with survival respectively.
# - Being alone (no family aboard) is associated with lower survival than having a small family (2-4),
#   while very large families had lower survival, likely reflecting difficulty evacuating together.
# - Age has a weaker, mildly negative relationship with survival (children had somewhat higher survival).

# %% [markdown]
# #### Important features

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

model_df = titanic_clean.copy()
cat_cols = ['Sex', 'Embarked']
for c in cat_cols:
    model_df[c] = LabelEncoder().fit_transform(model_df[c].astype(str))

features = ['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']
X = model_df[features]
y = model_df['Survived']

rf = RandomForestClassifier(n_estimators=300, random_state=42)
rf.fit(X, y)

importance = pd.Series(rf.feature_importances_, index=features).sort_values(ascending=False)
plt.figure(figsize=(8,5))
sns.barplot(x=importance.values, y=importance.index)
plt.title('Feature Importance for Survival (Random Forest)')
plt.xlabel('Importance')
plt.tight_layout()
plt.show()
importance
# Out:
# Fare        0.266984
# Age         0.265092
# Sex         0.255327
# Pclass      0.088890
# SibSp       0.049796
# Parch       0.038845
# Embarked    0.035068
# dtype: float64

# %% [markdown]
# #### Saving clean dataset

# %% [markdown]
# titanic_clean.to_csv('outputs/titanic_cleaned.csv', index=False)
# print('Saved outputs/titanic_cleaned.csv with shape', titanic_clean.shape)
# titanic_clean.head()

# %% [markdown]
# ## HOUSE PRICES DATASET

# %%
housing = pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\Housing.csv")
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
print(f'The number of rows:{housing. shape[0]}')
print(f'The number of columns: {housing.shape[1]}')
# Out:
# The number of rows:545
# The number of columns: 13

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
housing.describe(include='all').T
# Out:
#                   count unique             top freq            mean  \
# price             545.0    NaN             NaN  NaN  4766729.247706
# area              545.0    NaN             NaN  NaN     5150.541284
# bedrooms          545.0    NaN             NaN  NaN        2.965138
# bathrooms         545.0    NaN             NaN  NaN        1.286239
# stories           545.0    NaN             NaN  NaN        1.805505
# mainroad            545      2             yes  468             NaN
# guestroom           545      2              no  448             NaN
# basement            545      2              no  354             NaN
# hotwaterheating     545      2              no  520             NaN
# airconditioning     545      2              no  373             NaN
# parking           545.0    NaN             NaN  NaN        0.693578
# prefarea            545      2              no  417             NaN
# furnishingstatus    545      3  semi-furnished  227             NaN
#
# ...

# %% [markdown]
# #### Missing values

# %%
miss = housing.isnull().sum()
miss_pct = (miss / len(housing) * 100).round(2)
pd.DataFrame({'miss_count': miss, 'miss_pct': miss_pct}).query('miss_count > 0').sort_values('miss_count', ascending=False)
# Out:
# Empty DataFrame
# Columns: [miss_count, miss_pct]
# Index: []

# %% [markdown]
# #### Duplicates

# %%
dup = housing.duplicated().sum()
print(f'Rows with identical values across all columns: {dup}')
# Out:
# Rows with identical values across all columns: 0

# %% [markdown]
# #### Univariate analysis

# %%
housing.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 9))

sns.histplot(housing['price'], bins=40, kde=True, ax=axes[0,0])
axes[0,0].set_title('Price Distribution')

sns.histplot(housing['area'], bins=40, kde=True, ax=axes[0,1])
axes[0,1].set_title('Area Distribution')

sns.countplot(data=housing, x='bedrooms', ax=axes[0,2])
axes[0,2].set_title('Bedrooms Count')

sns.countplot(data=housing, x='bathrooms', ax=axes[1,0])
axes[1,0].set_title('Bathrooms Count')

sns.countplot(data=housing, x='stories', ax=axes[1,1])
axes[1,1].set_title('Stories Count')

sns.countplot(data=housing, x='parking', ax=axes[1,2])
axes[1,2].set_title('Parking Spaces Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Bivariate analysis

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 9))

sns.scatterplot(data=housing, x='area', y='price', alpha=0.5, ax=axes[0,0])
axes[0,0].set_title('Price vs Area')

sns.boxplot(data=housing, x='bedrooms', y='price', ax=axes[0,1])
axes[0,1].set_title('Price vs Bedrooms')

sns.boxplot(data=housing, x='bathrooms', y='price', ax=axes[0,2])
axes[0,2].set_title('Price vs Bathrooms')

sns.boxplot(data=housing, x='airconditioning', y='price', ax=axes[1,0])
axes[1,0].set_title('Price vs Air Conditioning (0=No, 1=Yes)')

sns.boxplot(data=housing, x='prefarea', y='price', ax=axes[1,1])
axes[1,1].set_title('Price vs Preferred Area (0=No, 1=Yes)')

sns.boxplot(data=housing, x='furnishingstatus', y='price', ax=axes[1,2])
axes[1,2].set_title('Price vs Furnishing Status')
axes[1,2].tick_params(axis='x', rotation=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Correlation heatmap

# %%
plt.figure(figsize=(11,8))
corr = housing.corr(numeric_only=True)
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlation Heatmap - Housing (all numeric/encoded features)')
plt.tight_layout()
plt.show()

# %%
corr['price'].drop('price').sort_values(ascending=False)
# Out:
# area         0.535997
# bathrooms    0.517545
# stories      0.420712
# parking      0.384394
# bedrooms     0.366494
# Name: price, dtype: float64

# %% [markdown]
# #### Encoding categorical values

# %%
categorical_columns = housing.select_dtypes(include=['object'])
print(categorical_columns.head())
# Out:
#   mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# 0      yes        no       no              no             yes      yes
# 1      yes        no       no              no             yes       no
# 2      yes        no      yes              no              no      yes
# 3      yes        no      yes              no             yes      yes
# 4      yes       yes      yes              no             yes       no
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
housing_clean = housing.copy()

binary_cols = ['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea']
for c in binary_cols:
    housing_clean[c] = housing_clean[c].map({'yes': 1, 'no': 0})

# One-hot encode furnishingstatus (3 categories)
housing_clean = pd.get_dummies(housing_clean, columns=['furnishingstatus'], drop_first=True)
bool_cols = housing_clean.select_dtypes(include='bool').columns
housing_clean[bool_cols] = housing_clean[bool_cols].astype(int)

housing_clean.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 0                                0                             0
# ...

# %% [markdown]
# #### Important features

# %%
from sklearn.ensemble import RandomForestRegressor

feature_cols = [c for c in housing_clean.columns if c != 'price']
X = housing_clean[feature_cols]
y = housing_clean['price']

rf = RandomForestRegressor(n_estimators=300, random_state=42)
rf.fit(X, y)

importance = pd.Series(rf.feature_importances_, index=feature_cols).sort_values(ascending=False)
plt.figure(figsize=(8,6))
sns.barplot(x=importance.values, y=importance.index)
plt.title('Feature Importance for Price (Random Forest)')
plt.xlabel('Importance')
plt.tight_layout()
plt.show()
importance
# Out:
# area                               0.460892
# bathrooms                          0.159623
# parking                            0.061386
# airconditioning                    0.055927
# stories                            0.054066
# bedrooms                           0.041921
# furnishingstatus_unfurnished       0.037962
# prefarea                           0.035757
# basement                           0.031196
# guestroom                          0.019427
# hotwaterheating                    0.016776
# furnishingstatus_semi-furnished    0.015824
# mainroad                           0.009244
# dtype: float64

# %% [markdown]
# # Summary of Insights
#
# ## Titanic Dataset
# - **Data quality:** `age` (~20% missing) was imputed by pclass/sex median; `deck` (~77% missing)
#   was dropped; `embarked`/`embark_town` (2 missing) were imputed with the mode. No duplicate rows found.
# - **Most predictive features (Random Forest):** `sex`, `fare`, `age`, and `pclass` dominate feature
#   importance, with `family_size` adding a smaller but real contribution.
# - **Key relationships:** women and 1st-class passengers survived at much higher rates than men and
#   3rd-class passengers; being completely alone or in a very large family was associated with lower
#   survival than a small family.
# - **Modeling implications:** `fare` is skewed and benefits from a log transform; categorical
#   variables (`sex`, `embarked`, `pclass`) should be encoded; `deck`/`alive` are either too sparse or
#   redundant with the target and can be dropped.
#
# ## House Prices Dataset
# - **Data quality:** the dataset is clean — no missing values and no duplicates, so effort went
#   into encoding categoricals (binary yes/no columns, one-hot for `furnishingstatus`) rather than
#   imputation.
# - **Most predictive features (Random Forest):** `area` is the dominant driver of price, followed by
#   `bathrooms`, `airconditioning`, and `stories`; `bedrooms` matters much less than area.
# - **Key relationships:** price rises with area, bathrooms, and stories; amenities like air
#   conditioning and being in a preferred area each shift prices upward; furnished homes tend to sell
#   for more than unfurnished ones.
# - **Modeling implications:** `price` is right-skewed (skew ≈ 1.2) — a log transform is recommended
#   for linear models; outliers at the high end appear to be genuine luxury properties, not data
#   errors, so they were retained rather than removed.
#
# ## Deliverables produced
# - `outputs/titanic_cleaned.csv` — cleaned, de-duplicated, imputed Titanic dataset with engineered
#   `family_size`/`is_alone` features.
# - `outputs/housing_cleaned.csv` — cleaned, fully-encoded housing dataset ready for modeling.
# - This notebook (`EDA_Titanic_and_Housing.ipynb`) with all cleaning steps, visualizations, and
#   feature-importance analysis.

# %% [markdown]
# # Week 3: Statistics & Probability

# %% [markdown]
# Objective
# • To understand statistical concepts used in data science.
#
#  Task Breakdown
# • Descriptive statistics (mean, variance, std dev)
# • Probability distributions
# • Hypothesis testing
# • Correlation vs causation

# %%
from scipy import stats

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (8, 5)
pd.set_option('display.max_columns', 50)
np.random.seed(42)

# %% [markdown]
# ### DESCRIPTIVE STATISTICS

# %% [markdown]
# #### Titanic numeric variables

# %%
a = titanic_clean.columns
print(a)
titanic_clean.dtypes
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'family_size',
#        'is_alone'],
#       dtype='object')
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# family_size      int64
# is_alone         int64
# dtype: object

# %%
num_cols_t =['Age', 'Fare', 'family_size', 'SibSp', 'Parch']

desc_t = pd.DataFrame({
    'mean': titanic_clean[num_cols_t].mean(),
    'median': titanic_clean[num_cols_t].median(),
    'variance': titanic_clean[num_cols_t].var(),
    'std_dev': titanic_clean[num_cols_t].std(),
    'skewness': titanic_clean[num_cols_t].skew(),
    'min': titanic_clean[num_cols_t].min(),
    'max': titanic_clean[num_cols_t].max(),
})
desc_t.round(2)
# Out:
#               mean  median  variance  std_dev  skewness   min     max
# Age          29.11   26.00    177.01    13.30      0.53  0.42   80.00
# Fare         32.20   14.45   2469.44    49.69      4.79  0.00  512.33
# family_size   1.90    1.00      2.60     1.61      2.73  1.00   11.00
# SibSp         0.52    0.00      1.22     1.10      3.70  0.00    8.00
# Parch         0.38    0.00      0.65     0.81      2.75  0.00    6.00

# %% [markdown]
# - `fare` has a mean (~32) well above its median (~14) with high positive skew — a small number
#   of very expensive tickets pull the mean upward, a classic sign that the median is the more
#   representative "typical" value here.
# - `age`'s mean and median are close, consistent with a roughly symmetric distribution.
# - Standard deviation of `fare` (~50) is *larger* than its own mean, which is another signal of a
#   long right tail rather than a tight, symmetric spread.

# %% [markdown]
# #### Housing numerical values

# %%
housing_clean.dtypes
# Out:
# price                              int64
# area                               int64
# bedrooms                           int64
# bathrooms                          int64
# stories                            int64
# mainroad                           int64
# guestroom                          int64
# basement                           int64
# hotwaterheating                    int64
# airconditioning                    int64
# parking                            int64
# prefarea                           int64
# furnishingstatus_semi-furnished    int64
# furnishingstatus_unfurnished       int64
# dtype: object

# %%
num_cols_h = ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']

desc_h = pd.DataFrame({
    'mean': housing_clean[num_cols_h].mean(),
    'median': housing_clean[num_cols_h].median(),
    'variance': housing_clean[num_cols_h].var(),
    'std_dev': housing_clean[num_cols_h].std(),
    'skewness': housing_clean[num_cols_h].skew(),
    'min': housing_clean[num_cols_h].min(),
    'max': housing_clean[num_cols_h].max(),
})
desc_h.round(2)
# Out:
#                  mean     median      variance     std_dev  skewness      min  \
# price      4766729.25  4340000.0  3.498544e+12  1870439.62      1.21  1750000
# area          5150.54     4600.0  4.709512e+06     2170.14      1.32     1650
# bedrooms         2.97        3.0  5.400000e-01        0.74      0.50        1
# bathrooms        1.29        1.0  2.500000e-01        0.50      1.59        1
# stories          1.81        2.0  7.500000e-01        0.87      1.08        1
# parking          0.69        0.0  7.400000e-01        0.86      0.84        0
#
#                 max
# price      13300000
# area          16200
# bedrooms          6
# bathrooms         4
# stories           4
# parking           3

# %% [markdown]
# - `price` and `area` both show mean > median and positive skew — the same "long right tail"
#   pattern as Titanic fare, driven by a handful of large, expensive properties.
# - `bedrooms`, `bathrooms`, and `stories` are discrete, low-range counts with much smaller
#   variance — most homes cluster tightly around 2–3 bedrooms and 1–2 bathrooms.
# - Variance is in *squared* units (e.g. rupees², sqft²), which is why standard deviation — same
#   units as the original variable — is the number practitioners usually report and interpret.

# %% [markdown]
# ####  Visualizing spread: mean vs. median under skew

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.histplot(titanic_clean['Fare'], bins=40, kde=True, ax=axes[0])
axes[0].axvline(titanic_clean['Fare'].mean(), color='red', linestyle='--', label=f"mean = {titanic_clean['Fare'].mean():.1f}")
axes[0].axvline(titanic_clean['Fare'].median(), color='green', linestyle='--', label=f"median = {titanic_clean['Fare'].median():.1f}")
axes[0].set_title('Titanic Fare: mean pulled right by skew')
axes[0].legend()

sns.histplot(housing_clean['price'], bins=40, kde=True, ax=axes[1])
axes[1].axvline(housing_clean['price'].mean(), color='red', linestyle='--', label=f"mean = {housing_clean['price'].mean():,.0f}")
axes[1].axvline(housing_clean['price'].median(), color='green', linestyle='--', label=f"median = {housing_clean['price'].median():,.0f}")
axes[1].set_title('Housing Price: mean pulled right by skew')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### PROBABILITY DISTRIBUTIONS

# %% [markdown]
# #### Is Titanic age approximately normal?

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.histplot(titanic_clean['Age'], bins=30, kde=True, stat='density', ax=axes[0])
x = np.linspace(titanic_clean['Age'].min(), titanic_clean['Age'].max(), 200)
axes[0].plot(x, stats.norm.pdf(x, titanic_clean['Age'].mean(), titanic_clean['Age'].std()), 'r-', lw=2, label='Normal fit')
axes[0].set_title('Age: histogram vs. fitted Normal curve')
axes[0].legend()

stats.probplot(titanic_clean['Age'], dist='norm', plot=axes[1])
axes[1].set_title('Age: Q-Q plot vs Normal')

plt.tight_layout()
plt.show()

shapiro_age = stats.shapiro(titanic_clean['Age'].sample(min(500, len(titanic)), random_state=1))
print(f'Shapiro-Wilk test for normality: W={shapiro_age.statistic:.4f}, p={shapiro_age.pvalue:.4g}')
# Out:
# Shapiro-Wilk test for normality: W=0.9587, p=1.275e-10

# %% [markdown]
# **Interpretation:**
# The Q-Q plot shows age tracking the diagonal reasonably well in the
# middle of the distribution but deviating in the tails (heavier at young ages due to the imputed
# group medians and the presence of children).
# The Shapiro-Wilk test's small p-value formally
# rejects exact normality,a reminder that real data is rarely *perfectly* normal, but the
# approximation is often "good enough" for many statistical methods.

# %% [markdown]
# #### Is fare log normal?

# %%
fare_positive = titanic_clean.loc[titanic_clean['Fare'] > 0, 'Fare']
log_fare = np.log(fare_positive)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.histplot(log_fare, bins=30, kde=True, stat='density', ax=axes[0])
x = np.linspace(log_fare.min(), log_fare.max(), 200)
axes[0].plot(x, stats.norm.pdf(x, log_fare.mean(), log_fare.std()), 'r-', lw=2, label='Normal fit')
axes[0].set_title('log(Fare): histogram vs fitted Normal curve')
axes[0].legend()

stats.probplot(log_fare, dist='norm', plot=axes[1])
axes[1].set_title('log(Fare): Q-Q plot vs Normal')

plt.tight_layout()
plt.show()

print('Skew of raw fare:', fare_positive.skew().round(2))
print('Skew of log fare:', log_fare.skew().round(2))
# Out:
# Skew of raw fare: 4.77
# Skew of log fare: 0.9

# %% [markdown]
# **Interpretation:**
# After a log transform, fare's skew drops sharply and the Q-Q plot hugs
# the diagonal far more closely,evidence that fare is better described as **log-normal** than
# normal. This is the statistical justification for log-transforming monetary variables before
# using models (like linear regression) that assume normally-distributed inputs or residuals.

# %% [markdown]
# #### Housing price: same log-normal pattern

# %%
log_price = np.log(housing['price'])

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.histplot(housing_clean['price'], bins=40, kde=True, stat='density', ax=axes[0], color='teal')
axes[0].set_title('Price: raw distribution (right-skewed)')

stats.probplot(log_price, dist='norm', plot=axes[1])
axes[1].set_title('log(Price): Q-Q plot vs Normal')

plt.tight_layout()
plt.show()

print('Skew of raw price:', housing_clean['price'].skew().round(2))
print('Skew of log price:', log_price.skew().round(2))
# Out:
# Skew of raw price: 1.21
# Skew of log price: 0.14

# %% [markdown]
# #### Survival as a Bernoulli / Binomial process

# %%
p_survive = titanic_clean['Survived'].mean()
n = len(titanic_clean)
print(f'Observed survival rate (p): {p_survive:.3f} over n={n} passengers')

# Simulate the binomial distribution implied by this rate and compare to a single real draw
simulated_survivors = np.random.binomial(n, p_survive, size=10000)

plt.figure(figsize=(8,5))
sns.histplot(simulated_survivors, bins=40, stat='density', color='steelblue', label='Simulated Binomial(n, p)')
plt.axvline(titanic_clean['Survived'].sum(), color='red', linestyle='--', label=f"Actual survivors = {titanic_clean['Survived'].sum()}")
plt.title('Survivor Count: Actual vs. Simulated Binomial Distribution')
plt.xlabel('Number of survivors')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Observed survival rate (p): 0.384 over n=891 passengers

# %% [markdown]
# **Interpretation:**
# Each passenger's survival is a yes/no (Bernoulli) outcome, so the total
# number of survivors out of `n` passengers follows a **Binomial(n, p)** distribution if survival
# were independent and identically distributed across passengers. The actual survivor count falls
# right in the middle of the simulated distribution — reassuring, but this simulation also
# *assumes* every passenger had the same survival probability `p`, which Part 3 shows is false:
# survival probability actually depended heavily on sex and class.

# %% [markdown]
# ### HYPOTHESIS TESTING

# %% [markdown]
# #### T-test — Does fare differ between survivors and non-survivors? (Titanic)
#
# - **H₀:** mean fare is the same for survivors and non-survivors.
# - **H₁:** mean fare differs between the two groups.

# %%
fare_survived = titanic_clean.loc[titanic_clean['Survived'] == 1, 'Fare']
fare_died = titanic_clean.loc[titanic_clean['Survived'] == 0, 'Fare']

t_stat, p_val = stats.ttest_ind(fare_survived, fare_died, equal_var=False)  # Welch's t-test
print(f'Survivors  -> mean fare = {fare_survived.mean():.2f}, n = {len(fare_survived)}')
print(f'Non-survivors -> mean fare = {fare_died.mean():.2f}, n = {len(fare_died)}')
print(f't-statistic = {t_stat:.3f}, p-value = {p_val:.4g}')

plt.figure(figsize=(7,5))
sns.boxplot(data=titanic_clean, x='Survived', y='Fare')
plt.ylim(0, 300)
plt.title(f'Fare by Survival (Welch t-test p={p_val:.2g})')
plt.tight_layout()
plt.show()
# Out:
# Survivors  -> mean fare = 48.40, n = 342
# Non-survivors -> mean fare = 22.12, n = 549
# t-statistic = 6.839, p-value = 2.699e-11

# %% [markdown]
# **Conclusion:**
# p-value « 0.05, so we reject H₀ — survivors paid a significantly higher
# average fare than non-survivors.
# (We use **Welch's t-test**, which doesn't assume equal
# variances between groups, appropriate here since fare's spread differs a lot by survival
# status.)

# %% [markdown]
# #### Chi-square test — Is survival associated with sex? (Titanic)
#
# - **H₀:** survival and sex are independent (no association).
# - **H₁:** survival and sex are associated.

# %%
contingency = pd.crosstab(titanic_clean['Sex'], titanic_clean['Survived'])
print(contingency)
print()

chi2, p_val, dof, expected = stats.chi2_contingency(contingency)
print(f'chi2 = {chi2:.2f}, dof = {dof}, p-value = {p_val:.4g}')

plt.figure(figsize=(6,5))
sns.heatmap(contingency, annot=True, fmt='d', cmap='Blues')
plt.title(f'Sex vs Survival Contingency Table (chi2 p={p_val:.2g})')
plt.tight_layout()
plt.show()
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109
#
# chi2 = 260.72, dof = 1, p-value = 1.197e-58

# %% [markdown]
# p-value « 0.05, so we reject H₀ — sex and survival are strongly associated,
# consistent with the "women and children first" evacuation pattern seen in the EDA notebook.

# %% [markdown]
# #### One-way ANOVA — Does average fare differ across passenger classes? (Titanic)
#
# - **H₀:** mean fare is equal across all three passenger classes.
# - **H₁:** at least one class has a different mean fare.

# %%
groups = [titanic_clean.loc[titanic_clean['Pclass'] == c, 'Fare'] for c in sorted(titanic_clean['Pclass'].unique())]
f_stat, p_val = stats.f_oneway(*groups)
print(f'F-statistic = {f_stat:.2f}, p-value = {p_val:.4g}')

plt.figure(figsize=(7,5))
sns.boxplot(data=titanic_clean, x='Pclass', y='Fare')
plt.ylim(0, 300)
plt.title(f'Fare by Passenger Class (ANOVA p={p_val:.2g})')
plt.tight_layout()
plt.show()
# Out:
# F-statistic = 242.34, p-value = 1.031e-84

# %% [markdown]
# p-value « 0.05 — average fare differs significantly across classes, exactly
# as expected (fare is essentially the price paid for class).

# %% [markdown]
# #### T-test — does air conditioning affect house price? (Housing)
#
# - **H₀:** mean price is the same for homes with and without air conditioning.
# - **H₁:** mean price differs.

# %%
price_ac = housing_clean.loc[housing_clean['airconditioning'] == 1, 'price']
price_no_ac = housing_clean.loc[housing_clean['airconditioning'] == 0, 'price']

t_stat, p_val = stats.ttest_ind(price_ac, price_no_ac, equal_var=False)
print(f'With AC    -> mean price = {price_ac.mean():,.0f}, n = {len(price_ac)}')
print(f'Without AC -> mean price = {price_no_ac.mean():,.0f}, n = {len(price_no_ac)}')
print(f't-statistic = {t_stat:.3f}, p-value = {p_val:.4g}')

plt.figure(figsize=(7,5))
sns.boxplot(data=housing_clean, x='airconditioning', y='price')
plt.title(f'Price by Air Conditioning (t-test p={p_val:.2g})')
plt.tight_layout()
plt.show()
# Out:
# With AC    -> mean price = 6,013,221, n = 172
# Without AC -> mean price = 4,191,940, n = 373
# t-statistic = 10.659, p-value = 2.804e-22

# %% [markdown]
# p-value « 0.05 — homes with air conditioning have a significantly higher
# average price. As Part 4 discusses, this doesn't mean installing AC *causes* a price jump on its
# own; AC is also correlated with larger, more modern, higher-amenity homes.

# %% [markdown]
# #### Correlation significance test — area vs. price (Housing)

# %%
r, p_val = stats.pearsonr(housing_clean['area'], housing_clean['price'])
print(f'Pearson r = {r:.3f}, p-value = {p_val:.4g}')
# Out:
# Pearson r = 0.536, p-value = 7.388e-42

# %% [markdown]
# The correlation (r ≈ 0.54) is moderate-to-strong and the p-value is
# essentially zero, so we're confident this relationship did not arise by chance in our sample of
# 545 homes. Statistical significance tells us the effect is *real* — it says nothing about
# *why* it exists

# %% [markdown]
# ###  Correlation vs. Causation

# %% [markdown]
# #### Titanic: does paying a higher fare cause survival?

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,5))

sns.barplot(data=titanic_clean, x='Pclass', y='Survived', ax=axes[0])
axes[0].set_title('Survival Rate by Class\n(the likely causal factor)')

sns.scatterplot(data=titanic_clean, x='Fare', y='Survived', hue='Pclass', alpha=0.5, ax=axes[1])
axes[1].set_title('Fare vs Survival, colored by Class\n(fare is a proxy, not the cause)')
axes[1].set_xlim(0, 300)

plt.tight_layout()
plt.show()

# Correlation between fare and survival, controlling for class by looking within each class
for c in sorted(titanic_clean['Pclass'].unique()):
    sub = titanic[titanic_clean['Pclass'] == c]
    r, p = stats.pointbiserialr(sub['Survived'], sub['Fare'])
    print(f'Class {c}: fare-survival correlation r={r:.2f}, p={p:.3f}, n={len(sub)}')
# Out:
# Class 1: fare-survival correlation r=0.19, p=0.005, n=216
# Class 2: fare-survival correlation r=0.10, p=0.183, n=184
# Class 3: fare-survival correlation r=0.00, p=0.984, n=491

# %% [markdown]
#  #### Housing: does air conditioning cause a higher price?

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,5))

sns.boxplot(data=housing_clean, x='airconditioning', y='area', ax=axes[0])
axes[0].set_title('Homes with AC also tend to be larger\n(a likely confounder)')

sns.scatterplot(data=housing_clean, x='area', y='price', hue='airconditioning', alpha=0.6, ax=axes[1])
axes[1].set_title('Price vs Area, colored by AC\n(area explains much of the AC price gap)')

plt.tight_layout()
plt.show()

print('Mean area with AC:', housing_clean.loc[housing_clean['airconditioning']==1, 'area'].mean().round(0))
print('Mean area without AC:', housing_clean.loc[housing_clean['airconditioning']==0, 'area'].mean().round(0))
# Out:
# Mean area with AC: 5861.0
# Mean area without AC: 4823.0
